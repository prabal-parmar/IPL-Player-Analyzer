# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('deliveries.csv')

# %%
dataset.drop_duplicates()
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
match_stats = pd.read_csv('Match_Info.csv')

# %%
match_stats
# Out:
#       match_number                        team1                        team2  \
# 0           392232  Royal Challengers Bangalore             Delhi Daredevils
# 1           548344        Kolkata Knight Riders  Royal Challengers Bangalore
# 2           392182  Royal Challengers Bangalore             Rajasthan Royals
# 3          1082646             Delhi Daredevils  Royal Challengers Bangalore
# 4           419108              Kings XI Punjab             Delhi Daredevils
# ...            ...                          ...                          ...
# 1164        980999  Royal Challengers Bangalore              Kings XI Punjab
# 1165        598008  Royal Challengers Bangalore        Kolkata Knight Riders
# 1166       1422128  Royal Challengers Bengaluru        Kolkata Knight Riders
# 1167       1254095          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1168       1359528  Royal Challengers Bangalore               Mumbai Indians
#
# ...

# %%
match_stats[match_stats['match_number'] == 335982]
# Out:
#       match_number                        team1                  team2  \
# 1096        335982  Royal Challengers Bangalore  Kolkata Knight Riders
#
#       match_date                  toss_winner toss_decision result eliminator  \
# 1096  2008-04-18  Royal Challengers Bangalore         field    Win        NaN
#
#                      winner player_of_match                  venue       city  \
# 1096  Kolkata Knight Riders     BB McCullum  M Chinnaswamy Stadium  Bangalore
#
#                                           team1_players  \
# 1096  R Dravid, W Jaffer, V Kohli, JH Kallis, CL Whi...
#
#                                           team2_players
# 1096  SC Ganguly, BB McCullum, RT Ponting, DJ Hussey...

# %%
dataset['match_id'].value_counts()
# Out:
# match_id
# 1216517    269
# 392190     267
# 1426268    265
# 1082625    263
# 729315     262
#           ...
# 392183     108
# 829807     106
# 598068     100
# 501265      63
# 1178424     51
# Name: count, Length: 1095, dtype: int64

# %%
dataset[['player_dismissed', 'dismissal_kind', 'extras_type', 'fielder']] = dataset[['player_dismissed', 'dismissal_kind', 'extras_type', 'fielder']].fillna("None")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       260920 non-null  object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  260920 non-null  object
#  15  dismissal_kind    260920 non-null  object
# ...

# %%
dataset.head(100)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ..       ...     ...                    ...                          ...
# 95    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 96    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 97    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 98    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 99    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
#
#     over  ball       batter     bowler  non_striker  batsman_runs  extra_runs  \
# ...

# %%
all_batters = dataset['batter'].unique().tolist()

# %%
all_bowlers = dataset['bowler'].unique().tolist()

# %%
all_bowlers
# Out:
# ['P Kumar',
#  'Z Khan',
#  'AA Noffke',
#  'JH Kallis',
#  'SB Joshi',
#  'CL White',
#  'AB Dinda',
#  'I Sharma',
#  'AB Agarkar',
#  'SC Ganguly',
#  'LR Shukla',
#  'B Lee',
#  'S Sreesanth',
#  'JR Hopes',
#  'IK Pathan',
#  'K Goel',
#  'PP Chawla',
#  'WA Mota',
#  'JDP Oram',
#  'MS Gony',
#  'M Muralitharan',
#  'P Amarnath',
#  'Joginder Sharma',
#  'GD McGrath',
#  'B Geeves',
#  'MF Maharoof',
#  'R Bhatia',
#  'DL Vettori',
#  'MM Patel',
#  'SR Watson',
#  'SK Trivedi',
#  'SK Warne',
#  'YK Pathan',
#  'D Salunkhe',
#  'R Vinay Kumar',
#  'B Akhil',
#  'A Nehra',
#  'SM Pollock',
#  'DS Kulkarni',
#  'ST Jayasuriya',
#  'Harbhajan Singh',
#  'AM Nayar',
#  'M Kartik',
#  'Mohammad Hafeez',
#  'DJ Hussey',
#  'WPUJC Vaas',
#  'RP Singh',
#  'SB Styris',
#  'SB Bangar',
#  'A Symonds',
#  'PP Ojha',
#  'Pankaj Singh',
#  'Mohammad Asif',
#  'VY Mahesh',
#  'Shahid Afridi',
#  'DJ Bravo',
#  'VS Yeligati',
#  'MA Khote',
#  'D Kalyankrishna',
#  'VRV Singh',
# ...

# %%
all_batters
# Out:
# ['SC Ganguly',
#  'BB McCullum',
#  'RT Ponting',
#  'DJ Hussey',
#  'Mohammad Hafeez',
#  'R Dravid',
#  'W Jaffer',
#  'V Kohli',
#  'JH Kallis',
#  'CL White',
#  'MV Boucher',
#  'B Akhil',
#  'AA Noffke',
#  'P Kumar',
#  'Z Khan',
#  'SB Joshi',
#  'PA Patel',
#  'ML Hayden',
#  'MEK Hussey',
#  'MS Dhoni',
#  'SK Raina',
#  'JDP Oram',
#  'S Badrinath',
#  'K Goel',
#  'JR Hopes',
#  'KC Sangakkara',
#  'Yuvraj Singh',
#  'SM Katich',
#  'IK Pathan',
#  'T Kohli',
#  'YK Pathan',
#  'SR Watson',
#  'M Kaif',
#  'DS Lehmann',
#  'RA Jadeja',
#  'M Rawat',
#  'D Salunkhe',
#  'SK Warne',
#  'SK Trivedi',
#  'G Gambhir',
#  'V Sehwag',
#  'S Dhawan',
#  'L Ronchi',
#  'ST Jayasuriya',
#  'DJ Thornely',
#  'RV Uthappa',
#  'PR Shah',
#  'AM Nayar',
#  'SM Pollock',
#  'Harbhajan Singh',
#  'S Chanderpaul',
#  'LRPL Taylor',
#  'AC Gilchrist',
#  'Y Venugopal Rao',
#  'VVS Laxman',
#  'A Symonds',
#  'RG Sharma',
#  'SB Styris',
#  'AS Yadav',
#  'SB Bangar',
#  'WPUJC Vaas',
# ...

# %%
sorted(all_batters)
# Out:
# ['A Ashish Reddy',
#  'A Badoni',
#  'A Chandila',
#  'A Chopra',
#  'A Choudhary',
#  'A Dananjaya',
#  'A Flintoff',
#  'A Kamboj',
#  'A Kumble',
#  'A Manohar',
#  'A Mishra',
#  'A Mithun',
#  'A Mukund',
#  'A Nehra',
#  'A Nortje',
#  'A Raghuvanshi',
#  'A Singh',
#  'A Symonds',
#  'A Tomar',
#  'A Uniyal',
#  'A Zampa',
#  'AA Bilakhia',
#  'AA Chavan',
#  'AA Jhunjhunwala',
#  'AA Kulkarni',
#  'AA Noffke',
#  'AB Agarkar',
#  'AB Barath',
#  'AB Dinda',
#  'AB McDonald',
#  'AB de Villiers',
#  'AC Blizzard',
#  'AC Gilchrist',
#  'AC Thomas',
#  'AC Voges',
#  'AD Hales',
#  'AD Mascarenhas',
#  'AD Mathews',
#  'AD Nath',
#  'AD Russell',
#  'AF Milne',
#  'AG Murtaza',
#  'AG Paunikar',
#  'AJ Finch',
#  'AJ Hosein',
#  'AJ Turner',
#  'AJ Tye',
#  'AK Markram',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AN Ahmed',
#  'AN Ghosh',
#  'AP Dole',
#  'AP Majumdar',
#  'AP Tare',
#  'AR Bawne',
#  'AR Patel',
#  'AS Joseph',
#  'AS Rajpoot',
#  'AS Raut',
# ...

# %%
all_players = all_batters + all_bowlers

# %%
ipl_players = []
for player in all_players:
    if player not in ipl_players:
        ipl_players.append(player)

# %%
len(ipl_players)
# Out:
# 732

# %%
batters_df = pd.DataFrame({'batter': ipl_players, 'runs': [0]*len(ipl_players)})

# %%
batters_df
# Out:
#               batter  runs
# 0         SC Ganguly     0
# 1        BB McCullum     0
# 2         RT Ponting     0
# 3          DJ Hussey     0
# 4    Mohammad Hafeez     0
# ..               ...   ...
# 727      M Siddharth     0
# 728         MP Yadav     0
# 729         S Joseph     0
# 730       N Thushara     0
# 731      V Kaverappa     0
#
# [732 rows x 2 columns]

# %%
temp = dataset[['batter', 'batsman_runs']]

# %%
temp
# Out:
#              batter  batsman_runs
# 0        SC Ganguly             0
# 1       BB McCullum             0
# 2       BB McCullum             0
# 3       BB McCullum             0
# 4       BB McCullum             0
# ...             ...           ...
# 260915      SS Iyer             1
# 260916      VR Iyer             1
# 260917      VR Iyer             1
# 260918      SS Iyer             1
# 260919      VR Iyer             1
#
# [260920 rows x 2 columns]

# %%
def find_total_score(batsman):
    new_df = temp[temp['batter'] == batsman]
    total_runs = 0
    for run in new_df['batsman_runs']:
        total_runs += int(run)
    return int(total_runs)

# %%
find_total_score('MS Dhoni')
# Out:
# 5243

# %%
batters_df
# Out:
#               batter  runs
# 0         SC Ganguly  1349
# 1        BB McCullum  2882
# 2         RT Ponting    91
# 3          DJ Hussey  1322
# 4    Mohammad Hafeez    64
# ..               ...   ...
# 727      M Siddharth     0
# 728         MP Yadav     0
# 729         S Joseph     0
# 730       N Thushara     0
# 731      V Kaverappa     0
#
# [732 rows x 2 columns]

# %%
batters_df = batters_df.sort_values(by='runs', ascending=False).reset_index(drop=True)

# %%
batters_df
# Out:
#               batter  runs
# 0            V Kohli  8014
# 1           S Dhawan  6769
# 2          RG Sharma  6630
# 3          DA Warner  6567
# 4           SK Raina  5536
# ..               ...   ...
# 727  Gagandeep Singh     0
# 728         B Geeves     0
# 729       P Amarnath     0
# 730          C Nanda     0
# 731      V Kaverappa     0
#
# [732 rows x 2 columns]

# %%
batters_df[batters_df['batter'] == "V Kohli"].index[0]
# Out:
# np.int64(0)

# %%
batters_df.iloc[0,1]
# Out:
# np.int64(0)

# %%
# batters_df.iloc[1,:]
for i in range(len(batters_df)):
    total_score = find_total_score(batters_df.iloc[i,0])
    batters_df.at[i, 'runs'] = total_score

# %%
dataset
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
bowlers_df = pd.DataFrame({'bowlers': ipl_players, 'wickets': [0]*len(ipl_players)})

# %%
bowlers_df.sort_values(by='wickets', ascending=False)
# Out:
#        bowlers  wickets
# 382  YS Chahal      205
# 67   PP Chawla      192
# 71    DJ Bravo      183
# 299    B Kumar      181
# 315  SP Narine      180
# ..         ...      ...
# 480   AD Hales        0
# 183    NV Ojha        0
# 477    PP Shaw        0
# 185    M Vijay        0
# 123   DT Patil        0
#
# [732 rows x 2 columns]

# %%
bowlers_stats = dataset[['bowler', 'is_wicket', 'dismissal_kind']]

# %%
bowlers_stats = bowlers_stats[~bowlers_stats['dismissal_kind'].isin(['run out', 'None', 'retired hurt', 'retired out', 'obstructing the field'])]

# %%
bowlers_stats
# Out:
#                bowler  is_wicket dismissal_kind
# 33             Z Khan          1         caught
# 74          JH Kallis          1         caught
# 106         AA Noffke          1         caught
# 131          I Sharma          1         bowled
# 138          AB Dinda          1         bowled
# ...               ...        ...            ...
# 260826   Harshit Rana          1         bowled
# 260848      SP Narine          1            lbw
# 260852     AD Russell          1         caught
# 260861     PJ Cummins          1         caught
# 260909  Shahbaz Ahmed          1            lbw
#
# [11815 rows x 3 columns]

# %%
bowlers_df
# Out:
#              bowlers  wickets
# 0         SC Ganguly       10
# 1        BB McCullum        0
# 2         RT Ponting        0
# 3          DJ Hussey        8
# 4    Mohammad Hafeez        2
# ..               ...      ...
# 727      M Siddharth        1
# 728         MP Yadav        7
# 729         S Joseph        0
# 730       N Thushara        8
# 731      V Kaverappa        2
#
# [732 rows x 2 columns]

# %%
def find_total_wickets(bowler):
    new_df = bowlers_stats[(bowlers_stats['bowler'] == bowler)]
    total_wickets = 0
    for wicket in new_df['is_wicket']:
        total_wickets += int(wicket)
    return int(total_wickets)

# %%
for i in range(len(bowlers_df)):
    total_wickets = find_total_wickets(bowlers_df.iloc[i,0])
    bowlers_df.at[i, 'wickets'] = total_wickets

# %%
bowlers_df[bowlers_df['bowlers'] == 'MS Dhoni']
# Out:
#      bowlers  wickets
# 19  MS Dhoni        0

# %%
balls = dataset['bowler']

# %%
balls
# Out:
# 0               P Kumar
# 1               P Kumar
# 2               P Kumar
# 3               P Kumar
# 4               P Kumar
#               ...
# 260915       AK Markram
# 260916       AK Markram
# 260917    Shahbaz Ahmed
# 260918    Shahbaz Ahmed
# 260919    Shahbaz Ahmed
# Name: bowler, Length: 260920, dtype: object

# %%
balls = balls.value_counts().reset_index()

# %%
balls
# Out:
#             bowler  count
# 0         R Ashwin   4679
# 1        SP Narine   4146
# 2          B Kumar   4060
# 3        PP Chawla   3895
# 4        RA Jadeja   3895
# ..             ...    ...
# 525        SN Khan      2
# 526      DA Warner      2
# 527   AC Gilchrist      1
# 528    YBK Jaiswal      1
# 529  Atharva Taide      1
#
# [530 rows x 2 columns]

# %%
ind_player = 'SS Iyer'

# %%
bat_team = dataset[(dataset['batter'] == ind_player)]

# %%
teams_played1 = bat_team['batting_team'].unique().tolist()

# %%
teams_played1
# Out:
# ['Delhi Daredevils', 'Delhi Capitals', 'Kolkata Knight Riders']

# %%
ball_team = dataset[(dataset['bowler'] == ind_player)]

# %%
teams_played1.extend(ball_team['bowling_team'].unique().tolist())

# %%
teams_played=[]
for team in teams_played1:
    if team not in teams_played:
        teams_played.append(team)

teams_played
# Out:
# ['Delhi Daredevils', 'Delhi Capitals', 'Kolkata Knight Riders']

# %%
match_stats['match_date'].describe
# Out:
# <bound method NDFrame.describe of 0       2009-05-19
# 1       2012-04-28
# 2       2009-04-18
# 3       2017-05-14
# 4       2010-03-13
#            ...
# 1164    2016-05-18
# 1165    2013-04-11
# 1166    2024-03-29
# 1167    2021-10-06
# 1168    2023-05-09
# Name: match_date, Length: 1169, dtype: object>

# %%
matches1 = match_stats[match_stats.apply(lambda row: ind_player in row['team1_players'] or row['result'] == 'Win', axis=1)]
matches2 = match_stats[match_stats.apply(lambda row: ind_player in row['team2_players'] or row['result'] == 'Win', axis=1)]

# %%
len(matches2) + len(matches1)
# Out:
# 2297

# %%
matches1 = match_stats[match_stats.apply(lambda row: ((ind_player in row['team1_players']) and (row['result'] == 'Win')) and (row['team1'] == row['winner']), axis=1)]

# %%
import datetime
date = match_stats['match_date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d").date()).tolist()

# %%
year = [x.year for x in date]

# %%
match_stats['year'] = year

# %%
match_stats.drop(columns=['match_date', 'toss_decision', 'venue', 'city', 'eliminator', 'match_number', 'toss_winner'], inplace=True)

# %%
player_matches = match_stats[match_stats.apply(lambda row: ind_player in row['team1_players'], axis=1)]

# %%
player_matches
# Out:
#                       team1                        team2 result  \
# 3          Delhi Daredevils  Royal Challengers Bangalore    Win
# 38           Delhi Capitals  Royal Challengers Bangalore    Win
# 57           Delhi Capitals             Rajasthan Royals    Win
# 62         Delhi Daredevils          Chennai Super Kings    Win
# 81           Delhi Capitals  Royal Challengers Bangalore    Win
# ...                     ...                          ...    ...
# 1085       Delhi Daredevils        Kolkata Knight Riders    Win
# 1090           Punjab Kings             Rajasthan Royals    Win
# 1111  Kolkata Knight Riders               Delhi Capitals    Win
# 1161  Kolkata Knight Riders                 Punjab Kings    Win
# 1163           Punjab Kings               Delhi Capitals    Win
#
#                            winner player_of_match  \
# 3     Royal Challengers Bangalore        HV Patel
# 38                 Delhi Capitals        S Dhawan
# ...

# %%
years = pd.DataFrame(columns=['team', 'year'])

# %%
years
# Out:
# Empty DataFrame
# Columns: [team, year]
# Index: []

# %%
years['team'] = teams_played

# %%
years
# Out:
#                     team year
# 0       Delhi Daredevils
# 1         Delhi Capitals
# 2  Kolkata Knight Riders

# %%
years['year'] = years['year'].fillna("")

# %%
match_stats[match_stats.apply(lambda row: ind_player in row['team1_players'], axis=1)][['team1', 'year']].reset_index(drop=True)
# Out:
#                     team1  year
# 0        Delhi Daredevils  2017
# 1          Delhi Capitals  2019
# 2          Delhi Capitals  2020
# 3        Delhi Daredevils  2015
# 4          Delhi Capitals  2021
# ..                    ...   ...
# 68       Delhi Daredevils  2015
# 69           Punjab Kings  2025
# 70  Kolkata Knight Riders  2024
# 71  Kolkata Knight Riders  2024
# 72           Punjab Kings  2025
#
# [73 rows x 2 columns]

# %%
teams_played
# Out:
# ['Delhi Daredevils', 'Delhi Capitals', 'Kolkata Knight Riders']

# %%
def find_year(team, ind_player):
    new_df = match_stats[match_stats.apply(lambda row: ind_player in row['team1_players'] and row['team1'] == team, axis=1)][['team1', 'year']].reset_index(drop=True)
    team1 = new_df['year'].unique().tolist()

    new_df = match_stats[match_stats.apply(lambda row: ind_player in row['team2_players'] and row['team2'] == team, axis=1)][['team2', 'year']].reset_index(drop=True)
    team2 = new_df['year'].unique().tolist()
    years = team1 + team2
    ans = []
    for year in years:
        if year not in ans:
            ans.append(year)

    return ans

# %%
find_year('Kolkata Knight Riders', ind_player)
# Out:
# [2022, 2024]

# %%
for i in range(len(years)):
    total_wickets = find_year(years.iloc[i,0])
    years.at[i, 'year'] += total_wickets + " "
